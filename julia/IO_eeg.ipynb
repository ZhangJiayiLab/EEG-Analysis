# %%
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
filename = "/Users/yizhan/Desktop/Observer/Data/Chen Zhou/EEG/Raw/180903-1/FA04831M.EEG"
rawdata = open(filename)

header = read(rawdata, UInt8, 1024*100)
header .|> Char |> String |> println

close(rawdata)

# %%
plot(header)

# %%
header[end-1024-10:end-1024+60] .|> Char |> String |> println
# Out:
# TIME194744000000	GDÐÇ
# ÀÀÀ
